# %% [markdown]
# #**using csv**

# %%
import pandas as pd
import io

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd /content/drive/My Drive/panda/
# Out:
# /content/drive/My Drive/panda

# %%
df = pd.read_csv("Weather_data.csv")
df
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2017           32          6    Rain
# 1  02-01-2017           35          5   Sunny
# 2  03-01-2017           28          8    snow
# 3  04-01-2017           26          9   Windy
# 4  05-01-2017           39          2  Moisty

# %% [markdown]
# #**Using excel**

# %%
df=pd.read_excel('Weather_data.xlsx')
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01           32          6    Rain
# 1 2017-01-02           35          5   Sunny
# 2 2017-01-03           28          8    snow
# 3 2017-01-04           26          9   Windy
# 4 2017-01-05           39          2  Moisty

# %% [markdown]
# #**Using dictionary**

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# #**Using tuples list**

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),  # this is the first row
    ('1/2/2017',35,7,'Sunny'),  # this is the second row and so on
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event']) # here we have to give the columns name
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# #**Using list of dictionaries**

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# #**some more methods to creatde a dataframe:==>> [link text](https://)https://pandas.pydata.org/docs/user_guide/io.html**
