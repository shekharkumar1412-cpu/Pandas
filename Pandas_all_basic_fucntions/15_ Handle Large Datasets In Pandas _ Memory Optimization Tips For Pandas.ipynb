# %% [markdown]
# https://www.youtube.com/watch?v=HNE0qHJ9A9o&ab_channel=codebasics

# %% [markdown]
# #**in order to optimize our code we can follow some tips listed in**
#
# 1.   https://pythonspeed.com/articles/pandas-load-less-data/
