# %% [markdown]
# #**pandas is a python module which makes data science effective and efficient**

# %% [markdown]
# **process of cleaning the data is called data munging/wrangling**

# %% [markdown]
# **Dataframe is a main object in panda. It is used to represent data with rows and columns similar to excel spreadsheet**

# %% [markdown]
# #**using python dictionary to create a dataframe**

# %%
import pandas as pd
wheather_data={
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(wheather_data)

df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# #**getting the size of the dataframe**

# %%
print(df.shape)
rows,columns=df.shape
print("no of rows is:",rows)
print("no of cols:",columns)
# Out:
# (6, 4)
# no of rows is: 6
# no of cols: 4

# %% [markdown]
# #**using head(N) to print first N rows of the dataframe**

# %%
print(df.head(3))
print("\nWithout passing any argument in the head function \n")
print(df.head())
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
#
# Without passing any argument in the head function
#
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %% [markdown]
# #**using tail(N) to print last N rows of the dataframe**

# %%
print(df.tail())
print("\n                                 Printing last 3 rows:")
df.tail(3)
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
#
#                                  Printing last 3 rows:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# #**slicing  is similar to a list**

# %%
print(df[1:4])
print()
print()
print()
print(df[0:5])
print()
print()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
#
#
#
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %% [markdown]
# #**printing columns of dataframe**

# %%
print(df.columns)
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df['event']   # df.event both are same
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %% [markdown]
# #**using type function to determine the type of any columns**

# %%
type(df['day'])
# Out:
# pandas.core.series.Series

# %%
type(df.day)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #**printing one or more columns of the dataframe**

# %%
print(df[['day','temperature']])
print()

print(df[['day','event','temperature']])
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31
#
#         day  event  temperature
# 0  1/1/2017   Rain           32
# 1  1/2/2017  Sunny           35
# 2  1/3/2017   Snow           28
# 3  1/4/2017   Snow           24
# 4  1/5/2017   Rain           32
# 5  1/6/2017  Sunny           31

# %% [markdown]
# #**operations of DataFrame**

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].mean()
# Out:
# 30.333333333333332

# %%
df['temperature'].min()
# Out:
# 24

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df['event'].max() # But mean() won't work since data type is string
# Out:
# 'Sunny'

# %% [markdown]
# #**using describe() method**

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %% [markdown]
# #**some sql query like Conditional select the data in your dataframe**

# %%
df[df['temperature']>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df[df.temperature==df.temperature.max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %% [markdown]
# #**To print required columns for the conditional select of the data**

# %%
df[['day','temperature']][df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %% [markdown]
# #**There are many methods for pandas among which some are discussed above and here is the link for all of the methods of the panda methods**

# %% [markdown]
# Google pandas series operations to find out list of all operations:-[link text](https://)http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html

# %% [markdown]
# #**set_index() and reset_index() methods**

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day')  # here the original dataframe is not modified
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %% [markdown]
#  **Modifying the index in the original dataframe**

# %%
df.set_index('day', inplace=True)
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %% [markdown]
# # **using loc('label') for label based indexing**

# %%
df.loc['1/2/2017']
# Out:
# temperature       35
# windspeed          7
# event          Sunny
# Name: 1/2/2017, dtype: object

# %% [markdown]
# #**Resetting the index in  the original Dataframe**

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %% [markdown]
# #**setting index = event in the original rested dataframe**

# %%
df.set_index('event',inplace=True) # this is kind of building a hash map using event as a key
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    event       day  temperature  windspeed
# 0   Rain  1/1/2017           32          6
# 1  Sunny  1/2/2017           35          7
# 2   Snow  1/3/2017           28          2
# 3   Snow  1/4/2017           24          7
# 4   Rain  1/5/2017           32          4
