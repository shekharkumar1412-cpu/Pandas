# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/My Drive/panda/
# Out:
# /content/drive/My Drive/panda

# %%
df=pd.read_csv('stock_data.csv')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# #**Index starts from 0 so header=1 means second row**

# %%
df=pd.read_csv('stock_data.csv',skiprows=2)
df
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
df=pd.read_csv('stock_data.csv',header=2)
df
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %% [markdown]
# #**in case of missing headers in a csv file we use (,header=None,names=['','',])**

# %%
df=pd.read_csv('stock_data.csv',header=None)
df
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df=pd.read_csv('stock_data.csv',header=None,names=['tickers','eps','revenue','price','people'])
df
# Out:
#    tickers            eps  revenue  price         people
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %% [markdown]
# #**Using nrows=n to read only n rows from the csv file**

# %%
df=pd.read_csv('stock_data.csv',nrows=3)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
df=pd.read_csv('stock_data.csv',nrows=4)
df
# Out:
#   tickers            eps  revenue  price         people
# 0   GOOGL          27.82       87    845     larry page
# 1     WMT           4.61      484     65           n.a.
# 2    MSFT             -1       85     64     bill gates
# 3    RIL   not available       50   1023  mukesh ambani

# %%
df=pd.read_csv('stock_data.csv')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# # **Clean up messy data from file "not available" and "n.a." replace with "na_values"**

# %%
df = pd.read_csv("stock_data.csv", na_values=["n.a.", "not available"])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %% [markdown]
# #**Supply dictionary for replace with "na_values"**

# %%
df = pd.read_csv("stock_data.csv",  na_values={
        'eps': ['not available','n.a.'],
        'revenue':['not available','n.a.',-1],
        'people': ['not available','n.a.']           # it means that in price when we encounter n.a or not available then replace that with na_values
    })
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %% [markdown]
# #**Write to CSV**

# %%
df.to_csv('new.csv')    # this will create a csv file named as new

# %% [markdown]
# #output
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #in order to remove the index we will add index=false

# %%
df.to_csv('new.csv',index=False)

# %% [markdown]
# #output
# ![image.png](data:image/png;base64,...)

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %% [markdown]
# #**Writtting some columns of df in the file new.csv**

# %%
df.to_csv('new.csv',index=False,columns=['tickers', 'eps', 'revenue'])

# %% [markdown]
# #output:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**writing into new.csv file without header**

# %%
df.to_csv('new.csv',header=False)

# %% [markdown]
# #output:
# ![image.png](data:image/png;base64,...)
